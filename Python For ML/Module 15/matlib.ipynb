# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 2d line plot
day = np.arange(1, 11)
temp = [30, 32, 34, 33, 31, 29, 28, 27, 26, 25]

plt.plot(day, temp, linestyle='-', color='r',marker='o')
plt.grid(True)
plt.xlabel('Day')
plt.ylabel('Temperature (°C)')
plt.title('Daily Temperature Over 10 Days')
# Out:
# Text(0.5, 1.0, 'Daily Temperature Over 10 Days')

# %%
df = pd.read_csv('enrollment_data.csv')

df.head()

plt.plot(df["Year"], df["Programming"], marker="o", linestyle="-", color="b",label="Programming")
plt.plot(df["Year"], df["Digital Marketing"], marker="s", linestyle="--", color="g",label="Digital Marketing")
plt.xlabel('Year')
plt.ylabel('Number of Enrollments')
plt.legend()
plt.show()

# %%
plt.scatter(df["Year"], df["Programming"], color="m", marker="^")
plt.scatter(df["Year"], df["Digital Marketing"], color="c", marker="x")
plt.xlabel('Year')
plt.ylabel('Number of Enrollments')
plt.legend(['Programming', 'Digital Marketing'])
plt.show()

# %%
students = pd.read_csv('student_IQdata.csv')

students.head()
# Out:
#    Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0       13.5         2.0            17.7        72
# 1        8.0        18.0             5.0        75
# 2        6.4         7.2            22.7        78
# 3        6.9         8.7             6.6       110
# 4       10.5         8.6             5.8       104

# %%
plt.scatter(students['Study_Hour'],students['IQ_Score'], color='b', marker='o')

plt.xlabel('Study Hours')
plt.ylabel('IQ Score')
plt.title('Study Hours vs IQ Score')
plt.grid(True)
plt.show()

# %%
# histogram

plt.hist(students['IQ_Score'], bins=10, color='g', edgecolor='black')
plt.xlabel('IQ Score')
plt.ylabel('Number of Students')
plt.title('Distribution of IQ Scores')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# bar chart
courses = ['Programming', 'Data Science', 'Digital Marketing', 'Cyber Security']
enrollments = [1200, 950, 800, 600]

plt.bar(courses, enrollments, color=['b', 'g', 'r', 'c'])
plt.xlabel('Courses')
plt.ylabel('Number of Enrollments')
plt.title('Enrollments in Different Courses')
plt.show()

# %%
# pie chart
labels = ['Programming', 'Data Science', 'Digital Marketing', 'Cyber Security']
sizes = [1200, 950, 800, 600]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140) # autopct %1.1f%% means one decimal place 
plt.title('Course Enrollment Distribution')
plt.axis('equal')
plt.show()
