# %%
import torch
import torch.nn as nn

# %%
class RNNModel(nn.Module):
    def __init__(self):
        super(RNNModel,self).__init__()
        self.run = nn.RNN(input_size=5,hidden_size=3,batch_first=True)
        self.fc = nn.Linear(3,1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self,x):
        out, _ = self.run(x)
        out = out[:,-1,:]
        out = self.fc(out)
        out = self.sigmoid(out)
        return out

# %%
model = RNNModel()
model
# Out:
# RNNModel(
#   (run): RNN(5, 3, batch_first=True)
#   (fc): Linear(in_features=3, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
# count trainable parameters
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'Total trainable parameters: {total_params}')
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f'{name}: {param.numel()} parameters')
# Out:
# Total trainable parameters: 34
# run.weight_ih_l0: 15 parameters
# run.weight_hh_l0: 9 parameters
# run.bias_ih_l0: 3 parameters
# run.bias_hh_l0: 3 parameters
# fc.weight: 3 parameters
# fc.bias: 1 parameters
