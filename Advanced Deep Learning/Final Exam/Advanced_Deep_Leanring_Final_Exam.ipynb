# %% [markdown]
# # NLP Exam
#  Notebook
#
# Fill in the blanks to complete each coding task. <br>
# Each question have 5 marks.

# %% [markdown]
# ## Q1: One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

words = [["cat"], ["dog"], ["bird"], ["cat"]]

encoder = __________()

encoded = encoder.____________(words)

print(encoded.toarray())

# %% [markdown]
# ## Q2: TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "I love NLP",
    "NLP is amazing",
    "Machine learning is fun"
]

vectorizer = ______________________()

tfidf_matrix = vectorizer.________________(documents)

print(tfidf_matrix.toarray())

# %% [markdown]
# ## Q3: CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

docs = ["apple orange apple","orange banana"]

vectorizer = ______________________()

matrix = vectorizer.________________(docs)

print(matrix.toarray())

# %% [markdown]
# ## Q4: Word2Vec

# %%
from gensim.models import Word2Vec

sentences = [
    ["I","love","NLP"],
    ["NLP","is","awesome"],
    ["Machine","learning","is","fun"]
]

model = Word2Vec(
    sentences,
    vector_size=_____,
    window=_____,
    min_count=_____
)

print(model.wv["NLP"])

# %% [markdown]
# ## Q5: Lowercase

# %%
text = "WELCOME TO NLP"

text = text.____________()

print(text)

# %% [markdown]
# ## Q6: Remove Punctuation

# %%
import re

text = "Hello!!! Welcome, to NLP."

clean_text = re.____________()

print(clean_text)

# %% [markdown]
# ## Q7: Remove Numbers

# %%
import re

text = "Python3 was released in 2008."

result = re.____________

print(result)

# %% [markdown]
# ## Q8: Extract Email

# %%
import re

text = """
Contact:
student@gmail.com
teacher@yahoo.com
"""

emails = re.____________(

)

print(emails)

# %% [markdown]
# ## Q9: Remove Extra Spaces

# %%
import re

text = "I      love       NLP"

text = re.sub().____________()

print(text)

# %% [markdown]
# ## Q10: Tokenization

# %%
text = "Natural Language Processing"

tokens = text.____________()

print(tokens)

# %% [markdown]
# ## Q11: Stopword Removal

# %%
from nltk.corpus import stopwords

words = ["I", "love", "to", "learn", "NLP"]

stop_words = set(stopwords.____________("english"))

filtered = [word for word in words if word.lower() not in ______________]

print(filtered)

# %% [markdown]
# ## Q12: Stemming

# %%
from nltk.stem import PorterStemmer

stemmer = __________________()

words = ["playing", "played", "plays"]

stems = [stemmer.____________(word) for word in words]

print(stems)

# %% [markdown]
# ## Q13: Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = __________________()

words = ["running", "better", "cars"]

lemmas = [lemmatizer.____________(word) for word in words]

print(lemmas)

# %% [markdown]
# ## Q14: Remove URLs

# %%
import re

text = "Visit https://google.com for more information."

clean = re.sub(

)

print(clean.____________())

# %% [markdown]
# ## Q15: Remove HTML

# %%
import re

html = "<h1>Welcome</h1><p>This is NLP.</p>"

#write rest of the code

# %% [markdown]
# ## Q16: Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

corpus = [
    "I love NLP",
    "NLP is fun"
]

#apply bag of words

# %% [markdown]
# ## Q17: Access Word2Vec Vector

# %%
from gensim.models import Word2Vec

sentences = [
    ["cat","dog","animal"],
    ["lion","tiger","animal"]
]

model = Word2Vec(sentences, vector_size=50, min_count=1)

vector = model.wv[____________]

print(vector)

# %% [markdown]
# ## Q18: Regex Phone

# %%
import re

text = "Call me at +8801712345678"

phone = re.findall(
    r"\+\d{13}",
    __________
)

print(phone)

# %% [markdown]
# ## Q19: Remove Special Characters

# %%
import re

text = "Hello@#$%^World!"

clean = re.sub(
    r"[^A-Za-z0-9\s]",
    "",
    __________
)

print(clean)

# %% [markdown]
# ## Q20: Complete NLP Preprocessing

# %%
import re

text = "Hello!!! Visit https://abc.com Email: student@gmail.com 123"

text = text.________________()

text = re.sub(r"https?://\S+", "", text)
text = re.sub(r"\S+@\S+", "", text)
text = re.sub(r"\d+", "", text)
text = re.sub(r"[^\w\s]", "", text)
text = re.sub(r"\s+", " ", text).________________()

print(text)

# %% [markdown]
# #Q: Optional :
#
# **Word2Vec**
#
# Explain the difference between **CBOW (Continuous Bag of Words)** and **Skip-Gram** architectures.
#
# Your answer should include:
# 1. How each model predicts words.
# 2. Which model performs better on small datasets.
# 3. Which model is better for learning rare words.
# 4. One practical advantage of Word2Vec over One-Hot Encoding.
