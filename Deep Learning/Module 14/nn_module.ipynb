# %% [markdown]
# # version 1

# %%
import torch
import torch.nn as nn

# %%
# class Model(nn.Module):
#   def __init__(self,num_features):
#     super().__init__()

#     self.linear = nn.Linear(num_features,1)
#     self.sigmoid = nn.Sigmoid()


#   def forward(self,features):
#     out = self.linear(features)
#     out = self.sigmoid(out)

#     return out

# %% [markdown]
# # Version 2

# %%
# class Model(nn.Module):
#   def __init__(self,num_features):
#     super().__init__()

#     #layer 1

#     self.linear1 = nn.Linear(num_features,3)
#     self.relu = nn.ReLU()

#     #layer 2
#     self.linear2 = nn.Linear(3,1)
#     self.sigmoid = nn.Sigmoid()


#   def forward(self,features):
#     out = self.linear1(features)
#     out = self.relu(out)

#     out = self.linear2(out)
#     out = self.sigmoid(out)

#     return out

# %%
# Version 3


class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()

    self.network = nn.Sequential(
        nn.Linear(num_features,3), #index 0
        nn.ReLU() ,   #index 1
        nn.Linear(3,1),  #index 2
        nn.Sigmoid()  #index 3

    )

  def forward(self,features):
    out = self.network(features)

    return out

# %%
# Create dataset

features = torch.rand(10,5)

# %%
features
# Out:
# tensor([[0.8586, 0.5855, 0.2756, 0.7868, 0.4615],
#         [0.1430, 0.1667, 0.8370, 0.3941, 0.1394],
#         [0.6905, 0.9492, 0.4124, 0.5287, 0.5941],
#         [0.9812, 0.4638, 0.1133, 0.3677, 0.9588],
#         [0.4797, 0.2341, 0.4883, 0.9957, 0.5547],
#         [0.9633, 0.0334, 0.5575, 0.3523, 0.6115],
#         [0.4270, 0.7268, 0.4923, 0.5199, 0.6281],
#         [0.1974, 0.3897, 0.3686, 0.5954, 0.4124],
#         [0.5874, 0.8238, 0.6701, 0.2595, 0.3166],
#         [0.1542, 0.7872, 0.9110, 0.2878, 0.7038]])

# %%
features.shape[1]
# Out:
# 5

# %%
#create model

model = Model(features.shape[1])

# %%
#calling model for forward pass
# model.forward(features)

model(features)
# Out:
# tensor([[0.6548],
#         [0.5609],
#         [0.6281],
#         [0.6816],
#         [0.6456],
#         [0.6575],
#         [0.6225],
#         [0.6197],
#         [0.5986],
#         [0.5916]], grad_fn=<SigmoidBackward0>)

# %%
#show model weights

model.network[3].weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 #show model weights
# ----> 3 model.network[3].weight
#
# File c:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1968, in Module.__getattr__(self, name)
#    1966     if name in modules:
#    1967         return modules[name]
# -> 1968 raise AttributeError(
#    1969     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1970 )
#
# AttributeError: 'Sigmoid' object has no attribute 'weight'

# %%
from torchinfo import summary

summary( model,input_size = (10,5) )
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [10, 1]                   --
# ├─Sequential: 1-1                        [10, 1]                   --
# │    └─Linear: 2-1                       [10, 3]                   18
# │    └─ReLU: 2-2                         [10, 3]                   --
# │    └─Linear: 2-3                       [10, 1]                   4
# │    └─Sigmoid: 2-4                      [10, 1]                   --
# ==========================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %% [markdown]
# # Extra

# %%
# Base Class
class Rectangle:
    def __init__(self, length, width):
        print("Rectangle constructor called")
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Child Class (Square inherits Rectangle)
class Square(Rectangle):
    def __init__(self, side):
        print("Square constructor called")
        super().__init__(side, side)   # Calls Rectangle constructor

    def square_info(self):
        return f"Square area: {self.area()}"


# Child Class (Cube inherits Square)
class Cube(Square):
    def __init__(self, side):
        print("Cube constructor called")
        super().__init__(side)   # Calls Square constructor

    def volume(self):
        return self.length ** 3


# Create Object
cube = Cube(4)

print("Area:", cube.area())
print("Volume:", cube.volume())
